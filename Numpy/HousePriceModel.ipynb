# %%
import pandas as pd

# %%
Dummy_data = pd.read_csv("./melb_data.csv")
# Display the first few rows of the DataFrame
print(Dummy_data.head())

# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/10.7 MB 8.4 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/10.7 MB 8.4 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/10.7 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.3/10.7 MB 7.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.1/10.7 MB 6.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.4/10.7 MB 6.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.4/10.7 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  10.5/10.7 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 6.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
# ...

# %%
import sklearn


print(sklearn.__version__)
# Out:
# 1.7.0
