# %%
import pandas as pd
import numpy as np
import matplotlib
import sys
matplotlib.use('Agg')  # Use a non-interactive backend for matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# printing version

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# series function to convert arr to colums with indexing

# %%
a = [1,2,3,4,5]
print(pd.Series(a))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
print(pd.Series(a, index=['a', 'b', 'c', 'd', 'e']))
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %% [markdown]
# DataFrame function creates a table formated structure of the given data

# %%
data = {'a': [1,2,3], 'b': [4,5,6], 'c': [7, None, None]}
DF = pd.DataFrame(data)
print(DF)
# Out:
#    a  b    c
# 0  1  4  7.0
# 1  2  5  NaN
# 2  3  6  NaN

# %%
print(DF.loc[[0,1]])
# Out:
#    a  b    c
# 0  1  4  7.0
# 1  2  5  NaN

# %%
df = pd.read_csv('data.txt')
print(df.to_string())
# Out:
#     ID             Name  Age Department  Salary Joining_Date
# 0    1         John Doe   28         IT   50000   2020-01-15
# 1    2       Jane Smith   34         HR   60000   2018-03-22
# 2    3      Emily Davis   29    Finance   55000   2019-07-10
# 3    4    Michael Brown   45         IT   75000   2015-11-01
# 4    5     Sarah Wilson   31  Marketing   48000   2021-06-18
# 5    6    David Johnson   38    Finance   67000   2017-09-12
# 6    7        Laura Lee   26         HR   52000   2022-02-25
# 7    8      James White   41         IT   80000   2014-05-30
# 8    9     Linda Harris   30  Marketing   47000   2020-08-14
# 9   10     Robert Clark   36    Finance   62000   2016-12-05
# 10  11   Patricia Lewis   27         HR   51000   2021-03-19
# 11  12   Charles Walker   50         IT   90000   2010-10-10
# 12  13     Barbara Hall   33  Marketing   49000   2019-04-23
# 13  14     Daniel Allen   40    Finance   71000   2016-07-08
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %% [markdown]
# for json file

# %%
df = pd.read_json('json_data.txt')
print(df.to_string())
# Out:
#     id     name  age           city
# 0    1    Alice   25       New York
# 1    2      Bob   30    Los Angeles
# 2    3  Charlie   22        Chicago
# 3    4    Diana   28        Houston
# 4    5      Eve   35        Phoenix
# 5    6    Frank   40   Philadelphia
# 6    7    Grace   27    San Antonio
# 7    8     Hank   33      San Diego
# 8    9      Ivy   29         Dallas
# 9   10     Jack   24       San Jose
# 10  11    Karen   31         Austin
# 11  12      Leo   26   Jacksonville
# 12  13     Mona   34     Fort Worth
# 13  14     Nate   21       Columbus
# 14  15   Olivia   32      Charlotte
# 15  16     Paul   36  San Francisco
# 16  17    Quinn   23   Indianapolis
# 17  18   Rachel   37        Seattle
# 18  19    Steve   38         Denver
# 19  20     Tina   39     Washington

# %% [markdown]
# Data cleaning:

# %% [markdown]
# remove rows containing at least one NaN value. dropna(). By default returns a new dataset, but usnig "inplace = true" will update the original dataset

# %%
df = pd.read_csv('unclean_data.txt')
# df.fillna(0, inplace=True)

new_df = df.dropna()
print(new_df.to_string())
# Out:
#                Name   Age                               Email  Salary  Joining Date
# 0          John Doe    29                john.doe@example.com   50000    2020-01-15
# 1        Jane Smith   NaN                  jane.smith@example   60000    2019-03-22
# 3       Emily Davis    42             emily.davis@example.com     NaN    2018-11-05
# 4       Chris Brown    28             chris.brown@example.com   52000    2020-02-30
# 5       Anna Taylor    31             anna.taylor@example.com   58000    2019-13-01
# 6     Michael Scott    45     michael.scott@dundermifflin.com   75000    2017-05-25
# 7    Dwight Schrute    38    dwight.schrute@dundermifflin.com     NaN    2016-09-12
# 8       Jim Halpert    32       jim.halpert@dundermifflin.com   62000    2018-04-31
# 9        Pam Beesly    30        pam.beesly@dundermifflin.com   61000    2019-06-15
# 10   Stanley Hudson    50    stanley.hudson@dundermifflin.com   70000    2015-08-20
# ...

# %% [markdown]
# replacing NaN values to any specific values. fillna()

# %% [markdown]
# visualize data.
#
# importing commands:
#     import matplotlib
#     import sys
#     matplotlib.use('Agg')  # Use a non-interactive backend for matplotlib
#     import matplotlib.pyplot as plt

# %%
df = pd.read_csv('visualize_data.txt')

# Plot the data
df.plot()

# Save the plot to an image file
plt.savefig('output.png')  # Saves the image

sys.stdout.flush()
